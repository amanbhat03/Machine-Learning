# %%
from keras.models import Sequential
from keras.layers import Dense

epoches = 200

model_keras = Sequential([
    Dense(hidden_dim, input_dim=input_dim, activation='sigmoid'),
    Dense(output_dim, activation='sigmoid')
])

model_keras.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])

history = model_keras.fit(X_train, y_train, epochs=epochs, verbose=0)

loss, accuracy = model_keras.evaluate(X_train, y_train)
print(f'Keras Model - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}')
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5111 - loss: 0.2503
# Keras Model - Loss: 0.2494, Accuracy: 0.5140

# %%
import matplotlib.pyplot as plt

epoches = 200
history = model_keras.fit(X_train, y_train, epochs=epochs, verbose=0)
loss = history.history['loss']
accuracy = history.history['accuracy']

plt.figure(figsize=(10, 5))
plt.plot(loss, label='Training Loss')
plt.title('Training Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(accuracy, label='Training Accuracy')
plt.title('Training Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

loss, accuracy = model_keras.evaluate(X_train, y_train)
print(f'Keras Model - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}')
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.4995 - loss: 0.2482
# Keras Model - Loss: 0.2476, Accuracy: 0.5210
