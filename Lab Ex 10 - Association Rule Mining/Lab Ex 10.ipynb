# %%
import pandas as pd
data = pd.read_csv('Market_Basket_Optimisation.csv')
data.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %%
def find_frequent_1_itemsets(transactions, min_support):
    item_counts = {}
    total_transactions = len(transactions)
    
    for transaction in transactions:
        for item in transaction:
            if item in item_counts:
                item_counts[item] += 1
            else:
                item_counts[item] = 1
    
    frequent_1_itemsets = {}
    for item, count in item_counts.items():
        support = count / total_transactions
        if support >= min_support:
            frequent_1_itemsets[frozenset([item])] = support
    
    return frequent_1_itemsets

def generate_candidate_itemsets(prev_frequent_itemsets, k):
    candidate_itemsets = []
    
    for itemset1 in prev_frequent_itemsets.keys():
        for itemset2 in prev_frequent_itemsets.keys():
            union_itemset = itemset1.union(itemset2)
            if len(union_itemset) == k and union_itemset not in candidate_itemsets:
                candidate_itemsets.append(union_itemset)
    
    return candidate_itemsets

def prune_candidate_itemsets(candidate_itemsets, prev_frequent_itemsets):
    
    pruned_itemsets = []
    
    for itemset in candidate_itemsets:
        subsets = [itemset.difference({item}) for item in itemset]
        if all(subset in prev_frequent_itemsets for subset in subsets):
            pruned_itemsets.append(itemset)
    
    return pruned_itemsets

def apriori(transactions, min_support):
    frequent_itemsets = {}
    k = 1
    
    frequent_1_itemsets = find_frequent_1_itemsets(transactions, min_support)
    frequent_itemsets.update(frequent_1_itemsets)
    
    while True:
        candidate_itemsets = generate_candidate_itemsets(frequent_itemsets, k+1)
        pruned_itemsets = prune_candidate_itemsets(candidate_itemsets, frequent_itemsets)
        
        itemset_counts = {}
        for itemset in pruned_itemsets:
            itemset_counts[itemset] = 0
            for transaction in transactions:
                if itemset.issubset(set(transaction)):
                    itemset_counts[itemset] += 1
        
        for itemset, count in itemset_counts.items():
            support = count / len(transactions)
            if support >= min_support:
                frequent_itemsets[itemset] = support
        
        if not pruned_itemsets:
            break
        
        k += 1
    
    return frequent_itemsets

min_support = 0.01 
frequent_itemsets = apriori(transactions, min_support)
print("Frequent Itemsets:")
for itemset, support in frequent_itemsets.items():
    print(itemset, "- Support:", support)
# Out:
# Frequent Itemsets:
# frozenset({'shrimp'}) - Support: 0.07145713904812692
# frozenset({'almonds'}) - Support: 0.020397280362618318
# frozenset({'avocado'}) - Support: 0.03332888948140248
# frozenset({'vegetables mix'}) - Support: 0.025729902679642713
# frozenset({'yams'}) - Support: 0.011465137981602452
# frozenset({'cottage cheese'}) - Support: 0.03186241834422077
# frozenset({'energy drink'}) - Support: 0.026663111585121985
# frozenset({'tomato juice'}) - Support: 0.030395947207039063
# frozenset({'low fat yogurt'}) - Support: 0.07652313024930009
# frozenset({'green tea'}) - Support: 0.13211571790427942
# frozenset({'honey'}) - Support: 0.047460338621517134
# frozenset({'mineral water'}) - Support: 0.23836821757099053
# frozenset({'salmon'}) - Support: 0.04252766297826956
# frozenset({'frozen smoothie'}) - Support: 0.06332489001466471
# frozenset({'olive oil'}) - Support: 0.0658578856152513
# frozenset({'burgers'}) - Support: 0.0871883748833489
# frozenset({'meatballs'}) - Support: 0.020930542594320756
# frozenset({'eggs'}) - Support: 0.17970937208372217
# frozenset({'turkey'}) - Support: 0.06252499666711105
# frozenset({'milk'}) - Support: 0.12958272230369283
# frozenset({'energy bar'}) - Support: 0.027063058258898813
# frozenset({'whole wheat rice'}) - Support: 0.058525529929342755
# frozenset({'whole wheat pasta'}) - Support: 0.029462738301559793
# frozenset({'french fries'}) - Support: 0.1709105452606319
# frozenset({'soup'}) - Support: 0.05052659645380616
# frozenset({'light cream'}) - Support: 0.01559792027729636
# frozenset({'frozen vegetables'}) - Support: 0.09532062391681109
# frozenset({'spaghetti'}) - Support: 0.17411011865084655
# frozenset({'cookies'}) - Support: 0.08038928142914278
# frozenset({'cooking oil'}) - Support: 0.0510598586855086
# frozenset({'champagne'}) - Support: 0.04679376083188908
# frozenset({'chocolate'}) - Support: 0.1639781362485002
# frozenset({'chicken'}) - Support: 0.05999200106652446
# frozenset({'oil'}) - Support: 0.023063591521130515
# frozenset({'fresh tuna'}) - Support: 0.022263698173576856
# frozenset({'tomatoes'}) - Support: 0.06839088121583789
# frozenset({'black tea'}) - Support: 0.014264764698040262
# frozenset({'extra dark chocolate'}) - Support: 0.011998400213304892
# frozenset({'protein bar'}) - Support: 0.01853086255165978
# frozenset({'red wine'}) - Support: 0.028129582722303693
# frozenset({'pasta'}) - Support: 0.01573123583522197
# frozenset({'pepper'}) - Support: 0.026529796027196375
# frozenset({'rice'}) - Support: 0.018797493667511
# frozenset({'ham'}) - Support: 0.027063058258898813
# frozenset({'body spray'}) - Support: 0.011465137981602452
# frozenset({'pancakes'}) - Support: 0.09505399280095987
# frozenset({'grated cheese'}) - Support: 0.0523930142647647
# frozenset({'white wine'}) - Support: 0.01653112918277563
# frozenset({'parmesan cheese'}) - Support: 0.01986401813091588
# frozenset({'fresh bread'}) - Support: 0.043060925209972005
# frozenset({'ground beef'}) - Support: 0.09825356619117451
# frozenset({'escalope'}) - Support: 0.0793227569657379
# frozenset({'herb & pepper'}) - Support: 0.04946007199040128
# frozenset({'tomato sauce'}) - Support: 0.014131449140114652
# frozenset({'magazines'}) - Support: 0.010931875749900012
# frozenset({'strawberries'}) - Support: 0.021330489268097587
# frozenset({'cake'}) - Support: 0.08105585921877083
# frozenset({'hot dogs'}) - Support: 0.03239568057592321
# frozenset({'brownies'}) - Support: 0.03372883615517931
# frozenset({'cereals'}) - Support: 0.025729902679642713
# frozenset({'muffins'}) - Support: 0.024130115984535395
# frozenset({'light mayo'}) - Support: 0.027196373816824423
# frozenset({'gums'}) - Support: 0.013464871350486601
# frozenset({'cider'}) - Support: 0.010531929076123183
# frozenset({'yogurt cake'}) - Support: 0.027329689374750034
# frozenset({'mint'}) - Support: 0.0174643380882549
# frozenset({'butter'}) - Support: 0.030129316091187842
# frozenset({'french wine'}) - Support: 0.022530329289428077
# frozenset({'barbecue sauce'}) - Support: 0.010798560191974404
# frozenset({'carrots'}) - Support: 0.01533128916144514
# frozenset({'mushroom cream sauce'}) - Support: 0.019064124783362217
# frozenset({'nonfat milk'}) - Support: 0.010398613518197574
# frozenset({'eggplant'}) - Support: 0.013198240234635382
# frozenset({'fromage blanc'}) - Support: 0.013598186908412212
# frozenset({'melons'}) - Support: 0.011998400213304892
# frozenset({'shrimp', 'green tea'}) - Support: 0.011465137981602452
# frozenset({'shrimp', 'mineral water'}) - Support: 0.023596853752832957
# frozenset({'shrimp', 'eggs'}) - Support: 0.014131449140114652
# frozenset({'milk', 'shrimp'}) - Support: 0.01759765364618051
# frozenset({'shrimp', 'frozen vegetables'}) - Support: 0.01666444474070124
# frozenset({'spaghetti', 'shrimp'}) - Support: 0.021197173710171976
# frozenset({'shrimp', 'chocolate'}) - Support: 0.017997600319957337
# frozenset({'tomatoes', 'shrimp'}) - Support: 0.011198506865751233
# frozenset({'shrimp', 'pancakes'}) - Support: 0.010531929076123183
# frozenset({'shrimp', 'ground beef'}) - Support: 0.011465137981602452
# frozenset({'mineral water', 'avocado'}) - Support: 0.011598453539528063
# frozenset({'mineral water', 'low fat yogurt'}) - Support: 0.023996800426609784
# frozenset({'low fat yogurt', 'eggs'}) - Support: 0.01679776029862685
# frozenset({'milk', 'low fat yogurt'}) - Support: 0.013198240234635382
# frozenset({'french fries', 'low fat yogurt'}) - Support: 0.013331555792560993
# frozenset({'frozen vegetables', 'low fat yogurt'}) - Support: 0.010131982402346354
# frozenset({'spaghetti', 'low fat yogurt'}) - Support: 0.015197973603519531
# frozenset({'chocolate', 'low fat yogurt'}) - Support: 0.014798026929742702
# frozenset({'mineral water', 'green tea'}) - Support: 0.03106252499666711
# frozenset({'frozen smoothie', 'green tea'}) - Support: 0.011198506865751233
# frozenset({'burgers', 'green tea'}) - Support: 0.0174643380882549
# frozenset({'green tea', 'eggs'}) - Support: 0.025463271563791495
# frozenset({'green tea', 'turkey'}) - Support: 0.011865084655379284
# frozenset({'milk', 'green tea'}) - Support: 0.01759765364618051
# frozenset({'french fries', 'green tea'}) - Support: 0.028529529396080524
# frozenset({'frozen vegetables', 'green tea'}) - Support: 0.01439808025596587
# frozenset({'spaghetti', 'green tea'}) - Support: 0.026529796027196375
# frozenset({'cookies', 'green tea'}) - Support: 0.011998400213304892
# frozenset({'chocolate', 'green tea'}) - Support: 0.023463538194907346
# frozenset({'chicken', 'green tea'}) - Support: 0.011865084655379284
# frozenset({'tomatoes', 'green tea'}) - Support: 0.012265031329156113
# frozenset({'green tea', 'pancakes'}) - Support: 0.01639781362485002
# frozenset({'ground beef', 'green tea'}) - Support: 0.014798026929742702
# frozenset({'cake', 'green tea'}) - Support: 0.014131449140114652
# frozenset({'mineral water', 'honey'}) - Support: 0.015064658045593921
# frozenset({'spaghetti', 'honey'}) - Support: 0.011865084655379284
# frozenset({'mineral water', 'salmon'}) - Support: 0.017064391414478068
# frozenset({'mineral water', 'frozen smoothie'}) - Support: 0.020263964804692707
# frozenset({'mineral water', 'olive oil'}) - Support: 0.027596320490601255
# frozenset({'mineral water', 'burgers'}) - Support: 0.024396747100386616
# frozenset({'mineral water', 'eggs'}) - Support: 0.05092654312758299
# frozenset({'mineral water', 'turkey'}) - Support: 0.019197440341287828
# frozenset({'milk', 'mineral water'}) - Support: 0.04799360085321957
# frozenset({'mineral water', 'whole wheat rice'}) - Support: 0.020130649246767097
# frozenset({'mineral water', 'french fries'}) - Support: 0.03372883615517931
# frozenset({'mineral water', 'soup'}) - Support: 0.023063591521130515
# frozenset({'frozen vegetables', 'mineral water'}) - Support: 0.03572856952406346
# frozenset({'spaghetti', 'mineral water'}) - Support: 0.05972536995067324
# frozenset({'cooking oil', 'mineral water'}) - Support: 0.020130649246767097
# frozenset({'chocolate', 'mineral water'}) - Support: 0.05265964538061592
# frozenset({'mineral water', 'chicken'}) - Support: 0.022796960405279298
# frozenset({'tomatoes', 'mineral water'}) - Support: 0.024396747100386616
# frozenset({'mineral water', 'red wine'}) - Support: 0.010931875749900012
# frozenset({'mineral water', 'pancakes'}) - Support: 0.03372883615517931
# frozenset({'grated cheese', 'mineral water'}) - Support: 0.0174643380882549
# frozenset({'mineral water', 'fresh bread'}) - Support: 0.013331555792560993
# frozenset({'ground beef', 'mineral water'}) - Support: 0.040927876283162246
# frozenset({'escalope', 'mineral water'}) - Support: 0.017064391414478068
# frozenset({'mineral water', 'herb & pepper'}) - Support: 0.017064391414478068
# frozenset({'cake', 'mineral water'}) - Support: 0.027463004932675644
# frozenset({'cereals', 'mineral water'}) - Support: 0.010265297960271964
# frozenset({'spaghetti', 'salmon'}) - Support: 0.013464871350486601
# frozenset({'chocolate', 'salmon'}) - Support: 0.010665244634048793
# frozenset({'frozen smoothie', 'eggs'}) - Support: 0.011065191307825623
# frozenset({'milk', 'frozen smoothie'}) - Support: 0.014264764698040262
# frozenset({'french fries', 'frozen smoothie'}) - Support: 0.014531395813891481
# frozenset({'spaghetti', 'frozen smoothie'}) - Support: 0.01559792027729636
# frozenset({'chocolate', 'frozen smoothie'}) - Support: 0.01493134248766831
# frozenset({'olive oil', 'eggs'}) - Support: 0.011998400213304892
# frozenset({'milk', 'olive oil'}) - Support: 0.017064391414478068
# frozenset({'frozen vegetables', 'olive oil'}) - Support: 0.011331822423676844
# frozenset({'spaghetti', 'olive oil'}) - Support: 0.022930275963204905
# frozenset({'chocolate', 'olive oil'}) - Support: 0.01639781362485002
# frozenset({'olive oil', 'pancakes'}) - Support: 0.010798560191974404
# frozenset({'ground beef', 'olive oil'}) - Support: 0.014131449140114652
# frozenset({'burgers', 'eggs'}) - Support: 0.02879616051193174
# frozenset({'burgers', 'turkey'}) - Support: 0.010665244634048793
# frozenset({'milk', 'burgers'}) - Support: 0.01786428476203173
# frozenset({'french fries', 'burgers'}) - Support: 0.021997067057725635
# frozenset({'frozen vegetables', 'burgers'}) - Support: 0.010531929076123183
# frozenset({'spaghetti', 'burgers'}) - Support: 0.021463804826023197
# frozenset({'chocolate', 'burgers'}) - Support: 0.017064391414478068
# frozenset({'burgers', 'pancakes'}) - Support: 0.010531929076123183
# frozenset({'ground beef', 'burgers'}) - Support: 0.011998400213304892
# frozenset({'cake', 'burgers'}) - Support: 0.011465137981602452
# frozenset({'turkey', 'eggs'}) - Support: 0.01946407145713905
# frozenset({'milk', 'eggs'}) - Support: 0.03079589388081589
# frozenset({'whole wheat rice', 'eggs'}) - Support: 0.010931875749900012
# frozenset({'french fries', 'eggs'}) - Support: 0.036395147313691506
# frozenset({'frozen vegetables', 'eggs'}) - Support: 0.021730435941874418
# frozenset({'spaghetti', 'eggs'}) - Support: 0.036528462871617116
# frozenset({'cookies', 'eggs'}) - Support: 0.010531929076123183
# frozenset({'cooking oil', 'eggs'}) - Support: 0.011731769097453673
# frozenset({'chocolate', 'eggs'}) - Support: 0.03319557392347687
# frozenset({'chicken', 'eggs'}) - Support: 0.01439808025596587
# frozenset({'tomatoes', 'eggs'}) - Support: 0.012265031329156113
# frozenset({'pancakes', 'eggs'}) - Support: 0.021730435941874418
# frozenset({'ground beef', 'eggs'}) - Support: 0.019997333688841486
# frozenset({'escalope', 'eggs'}) - Support: 0.011065191307825623
# frozenset({'herb & pepper', 'eggs'}) - Support: 0.012531662445007332
# frozenset({'cake', 'eggs'}) - Support: 0.019064124783362217
# frozenset({'milk', 'turkey'}) - Support: 0.011331822423676844
# frozenset({'french fries', 'turkey'}) - Support: 0.010665244634048793
# frozenset({'spaghetti', 'turkey'}) - Support: 0.01653112918277563
# frozenset({'chocolate', 'turkey'}) - Support: 0.011331822423676844
# frozenset({'milk', 'whole wheat rice'}) - Support: 0.011865084655379284
# frozenset({'milk', 'french fries'}) - Support: 0.023730169310758567
# frozenset({'milk', 'soup'}) - Support: 0.015197973603519531
# frozenset({'milk', 'frozen vegetables'}) - Support: 0.023596853752832957
# frozenset({'milk', 'spaghetti'}) - Support: 0.03546193840821224
# frozenset({'milk', 'cooking oil'}) - Support: 0.011465137981602452
# frozenset({'milk', 'chocolate'}) - Support: 0.03212904946007199
# frozenset({'milk', 'chicken'}) - Support: 0.014798026929742702
# frozenset({'milk', 'tomatoes'}) - Support: 0.013998133582189041
# frozenset({'milk', 'pancakes'}) - Support: 0.01653112918277563
# frozenset({'milk', 'ground beef'}) - Support: 0.021997067057725635
# frozenset({'milk', 'cake'}) - Support: 0.013331555792560993
# frozenset({'french fries', 'whole wheat rice'}) - Support: 0.010531929076123183
# frozenset({'spaghetti', 'whole wheat rice'}) - Support: 0.014131449140114652
# frozenset({'chocolate', 'whole wheat rice'}) - Support: 0.011998400213304892
# frozenset({'frozen vegetables', 'french fries'}) - Support: 0.019064124783362217
# frozenset({'spaghetti', 'french fries'}) - Support: 0.027596320490601255
# frozenset({'french fries', 'cookies'}) - Support: 0.013331555792560993
# frozenset({'chocolate', 'french fries'}) - Support: 0.03439541394480736
# frozenset({'french fries', 'chicken'}) - Support: 0.011065191307825623
# frozenset({'tomatoes', 'french fries'}) - Support: 0.011998400213304892
# frozenset({'french fries', 'pancakes'}) - Support: 0.020130649246767097
# frozenset({'grated cheese', 'french fries'}) - Support: 0.010398613518197574
# frozenset({'ground beef', 'french fries'}) - Support: 0.01386481802426343
# frozenset({'escalope', 'french fries'}) - Support: 0.01639781362485002
# frozenset({'cake', 'french fries'}) - Support: 0.01786428476203173
# frozenset({'spaghetti', 'soup'}) - Support: 0.014264764698040262
# frozenset({'chocolate', 'soup'}) - Support: 0.010131982402346354
# frozenset({'spaghetti', 'frozen vegetables'}) - Support: 0.027862951606452472
# frozenset({'chocolate', 'frozen vegetables'}) - Support: 0.022930275963204905
# frozenset({'tomatoes', 'frozen vegetables'}) - Support: 0.0161311825089988
# frozenset({'frozen vegetables', 'pancakes'}) - Support: 0.013464871350486601
# frozenset({'ground beef', 'frozen vegetables'}) - Support: 0.01693107585655246
# frozenset({'cake', 'frozen vegetables'}) - Support: 0.010265297960271964
# frozenset({'spaghetti', 'cooking oil'}) - Support: 0.01586455139314758
# frozenset({'spaghetti', 'chocolate'}) - Support: 0.03919477403012932
# frozenset({'spaghetti', 'chicken'}) - Support: 0.01719770697240368
# frozenset({'spaghetti', 'tomatoes'}) - Support: 0.020930542594320756
# frozenset({'spaghetti', 'red wine'}) - Support: 0.010265297960271964
# frozenset({'spaghetti', 'pancakes'}) - Support: 0.025196640447940274
# frozenset({'spaghetti', 'grated cheese'}) - Support: 0.01653112918277563
# frozenset({'spaghetti', 'ground beef'}) - Support: 0.03919477403012932
# frozenset({'spaghetti', 'escalope'}) - Support: 0.013998133582189041
# frozenset({'spaghetti', 'herb & pepper'}) - Support: 0.01626449806692441
# frozenset({'spaghetti', 'cake'}) - Support: 0.018130915877882948
# frozenset({'chocolate', 'cookies'}) - Support: 0.010398613518197574
# frozenset({'cooking oil', 'chocolate'}) - Support: 0.013598186908412212
# frozenset({'chocolate', 'champagne'}) - Support: 0.011598453539528063
# frozenset({'chocolate', 'chicken'}) - Support: 0.014664711371817091
# frozenset({'tomatoes', 'chocolate'}) - Support: 0.013998133582189041
# frozenset({'chocolate', 'pancakes'}) - Support: 0.01986401813091588
# frozenset({'chocolate', 'grated cheese'}) - Support: 0.010931875749900012
# frozenset({'chocolate', 'ground beef'}) - Support: 0.023063591521130515
# frozenset({'escalope', 'chocolate'}) - Support: 0.01759765364618051
# frozenset({'chocolate', 'cake'}) - Support: 0.013598186908412212
# frozenset({'tomatoes', 'ground beef'}) - Support: 0.011731769097453673
# frozenset({'ground beef', 'pancakes'}) - Support: 0.014531395813891481
# frozenset({'cake', 'pancakes'}) - Support: 0.011865084655379284
# frozenset({'grated cheese', 'ground beef'}) - Support: 0.011331822423676844
# frozenset({'ground beef', 'herb & pepper'}) - Support: 0.015997866951073192
# frozenset({'spaghetti', 'mineral water', 'olive oil'}) - Support: 0.010265297960271964
# frozenset({'milk', 'mineral water', 'eggs'}) - Support: 0.013064924676709772
# frozenset({'spaghetti', 'mineral water', 'eggs'}) - Support: 0.014264764698040262
# frozenset({'chocolate', 'mineral water', 'eggs'}) - Support: 0.013464871350486601
# frozenset({'ground beef', 'mineral water', 'eggs'}) - Support: 0.010131982402346354
# frozenset({'milk', 'mineral water', 'frozen vegetables'}) - Support: 0.011065191307825623
# frozenset({'milk', 'mineral water', 'spaghetti'}) - Support: 0.01573123583522197
# frozenset({'milk', 'chocolate', 'mineral water'}) - Support: 0.013998133582189041
# frozenset({'milk', 'ground beef', 'mineral water'}) - Support: 0.011065191307825623
# frozenset({'spaghetti', 'mineral water', 'french fries'}) - Support: 0.010131982402346354
# frozenset({'spaghetti', 'mineral water', 'frozen vegetables'}) - Support: 0.011998400213304892
# frozenset({'spaghetti', 'chocolate', 'mineral water'}) - Support: 0.01586455139314758
# frozenset({'spaghetti', 'mineral water', 'pancakes'}) - Support: 0.011465137981602452
# frozenset({'spaghetti', 'ground beef', 'mineral water'}) - Support: 0.017064391414478068
# frozenset({'chocolate', 'mineral water', 'ground beef'}) - Support: 0.010931875749900012
# frozenset({'spaghetti', 'chocolate', 'eggs'}) - Support: 0.010531929076123183
# frozenset({'milk', 'chocolate', 'spaghetti'}) - Support: 0.010931875749900012
