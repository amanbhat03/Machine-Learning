# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('house_pred.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data = pd.read_csv('house_pred.csv')
data = data.drop("Fence", axis=1)
data = data.drop("MiscFeature", axis=1)
data = data.drop("MiscVal", axis=1)
data = data.drop("Alley", axis=1)
data = data.drop("PoolQC", axis=1)

data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside  ...          61             0         0           0
# 1    AllPub       FR2  ...           0             0         0           0
# 2    AllPub    Inside  ...          42             0         0           0
# 3    AllPub    Corner  ...          35           272         0           0
# 4    AllPub       FR2  ...          84             0         0           0
#
#   PoolArea MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0        0      2    2008        WD         Normal     208500
# 1        0      5    2007        WD         Normal     181500
# 2        0      9    2008        WD         Normal     223500
# 3        0      2    2006        WD        Abnorml     140000
# 4        0     12    2008        WD         Normal     250000
#
# [5 rows x 76 columns]

# %%
data = pd.read_csv('house_pred.csv')
data_cleaned = data.dropna(axis=1)
data_cleaned.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# 1       FR2       Gtl  ...             0         0           0        0
# 2    Inside       Gtl  ...             0         0           0        0
# 3    Corner       Gtl  ...           272         0           0        0
# 4       FR2       Gtl  ...             0         0           0        0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0       0       2    2008        WD         Normal    208500
# 1       0       5    2007        WD         Normal    181500
# 2       0       9    2008        WD         Normal    223500
# 3       0       2    2006        WD        Abnorml    140000
# 4       0      12    2008        WD         Normal    250000
#
# [5 rows x 62 columns]

# %%
X = data.drop('SalePrice', axis=1)
y = data['SalePrice'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 940263064.4949743

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs. Predicted House Prices")
plt.show()

# %%
data = pd.read_csv('test.csv')
data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1205          20       RL         78.0    10140   Pave   NaN      Reg
# 1  1206          20       RL         90.0    14684   Pave   NaN      IR1
# 2  1207          20       RH          NaN     8900   Pave   NaN      Reg
# 3  1208          20       RL         70.0     9135   Pave   NaN      Reg
# 4  1209          20       RL         70.0     7763   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2006        WD         Normal
# 1       0      6    2009        WD         Normal
# 2       0     11    2006        WD         Normal
# 3       0      5    2006        WD         Normal
# 4       0     10    2008        WD         Normal
#
# [5 rows x 80 columns]

# %%
data = pd.read_csv('test.csv')
data_cleaned = data.dropna(axis=1)
data_cleaned.head()
# Out:
#      Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0  1205          20       RL    10140   Pave      Reg         Lvl    AllPub
# 1  1206          20       RL    14684   Pave      IR1         Lvl    AllPub
# 2  1207          20       RH     8900   Pave      Reg         Lvl    AllPub
# 3  1208          20       RL     9135   Pave      Reg         Lvl    AllPub
# 4  1209          20       RL     7763   Pave      Reg         Lvl    AllPub
#
#   LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    Inside       Gtl  ...          88             0         0           0
# 1   CulDSac       Gtl  ...          70             0         0           0
# 2    Inside       Gtl  ...          42             0         0           0
# 3    Inside       Gtl  ...          23             0         0           0
# 4    Inside       Gtl  ...           0             0         0           0
#
#   PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition
# 0        0        0       7    2006        WD        Normal
# 1        0        0       6    2009        WD        Normal
# 2        0        0      11    2006        WD        Normal
# 3        0        0       5    2006        WD        Normal
# 4        0        0      10    2008        WD        Normal
#
# [5 rows x 61 columns]

# %%
train_data = pd.read_csv('house_pred.csv')
test_data = pd.read_csv('test.csv')

X_train = train_data.drop('SalePrice', axis=1)
y_train = train_data['SalePrice'] 

model.fit(X_train, y_train)

X_test = test_data.copy()  

y_pred = model.predict(X_test)

print("Predicted House Prices:")
print(y_pred)
# Out:
# Predicted House Prices:
# [143678.0547191  248441.06296832 120044.48311727 212787.83410545
#  143581.19840641 292216.33422347 198005.29399324 178080.56757017
#   95232.06407297 138859.60108117 125542.68516458 103746.48064474
#  120334.16380389 231217.0398287   66223.23298059  91170.02565507
#  101983.29763225 123725.92569956 166735.49815615 142901.30567627
#  205767.84580207 138137.19596742 232924.72547889 151091.28629739
#  349528.00013729 132965.96017844 197397.60966166 132073.18277884
#   78875.38114416 130946.1942587  115974.53981654 150264.29166406
#  179819.56923273 209561.62985518 143027.96973958 242408.36714899
#  207435.53666455 242409.7952421  175668.16119625 409834.16701342
#  228699.44084649 213359.03295958 204370.14462988 147834.27930855
#  151431.58447738 123077.77796309 282284.91485729 194206.10432488
